# %%
import pandas as pd
import numpy as np
import datetime

# %%
train = pd.read_csv('./output/train.csv')    
test = pd.read_csv('./output/test.csv')    
test2 = pd.read_csv('./output/test2.csv')

def within_measure(x, y):
    #  3750901.5068 ≤ 𝑥 ≤ 3770901.5068
    #  −19268905.6133 ≤ 𝑦 ≤ −19208905.6133
    if 3750901.5068 <= x and x <= 3770901.5068 and -19268905.6133 <= y and y <= -19208905.6133:
        return 1
    else:
        return 0

for col in ['vmean','vmin','vmax']:
    mode = train[col].mode()[0]
    test[col].fillna(0, inplace=True)
    test2[col].fillna(0, inplace=True)
    train[col].fillna(0, inplace=True)    
    
train = train.append(test[test.x_exit==test.x_exit])
columns=[#'hash', 'trajectory_id', 
         'time_entry', 'time_exit', 'vmax', 'vmin',
       'vmean', 'x_entry', 'y_entry', 'first', 'last',
       'x_req', 'y_req', 'x_start', 'y_start', 'distance', 'time_start',
       'time_delta', 'time_total', 'city_start', 'city_now', 'city_was',
       'x_dir', 'y_dir', 'len',
         #'distance_to_city', 'speed','x_exit', 'y_exit', 
        ]
x_train = train[columns]
x_test = test2[columns]


y_train=pd.DataFrame()
#y_train=train[['x_exit','y_exit']]
y_train=[within_measure(x, y) for x,y in zip(train.x_exit.values,train.y_exit.values)]
y_train=pd.DataFrame({'y':y_train})

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 983684 entries, 0 to 202935
# Data columns (total 23 columns):
# time_entry    983684 non-null int64
# time_exit     983684 non-null int64
# vmax          983684 non-null float64
# vmin          983684 non-null float64
# vmean         983684 non-null float64
# x_entry       983684 non-null float64
# y_entry       983684 non-null float64
# first         983684 non-null bool
# last          983684 non-null bool
# x_req         983684 non-null float64
# y_req         983684 non-null float64
# x_start       983684 non-null float64
# y_start       983684 non-null float64
# distance      983684 non-null float64
# time_start    983684 non-null int64
# time_delta    983684 non-null int64
# time_total    983684 non-null int64
# city_start    983684 non-null bool
# city_now      983684 non-null bool
# city_was      983684 non-null bool
# x_dir         983684 non-null float64
# y_dir         983684 non-null float64
# len           983684 non-null int64
# dtypes: bool(5), float64(12), int64(6)
# memory usage: 147.3 MB

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983684 entries, 0 to 983683
# Data columns (total 1 columns):
# y    983684 non-null int64
# dtypes: int64(1)
# memory usage: 7.5 MB

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import DBSCAN

import matplotlib.pyplot as plt
import matplotlib.patches as patches

_eps = 175
_min_samples = 50

columns=['x_entry','y_entry']
data=train[columns]
trainend=np.shape(data)[0]
#data=data.append(test[columns])
#testend=np.shape(data)[0]
data=data.append(test2[columns])

_min_samples=40
_eps=190

c = DBSCAN(eps=_eps,
            min_samples=_min_samples,
            n_jobs=-1
            ).fit_predict(data)

labels=list(np.unique(c))
clusters=len(labels)
train_c=c[:trainend]
#test_c=c[trainend:testend]
test2_c=c[trainend:]
x_train['cluster']=train_c
x_test['cluster']=test2_c
# Out:
# C:\Users\J.K. Pawłowski\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\J.K. Pawłowski\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from random import randint

# parameters for LightGBMClassifier
params = {
    'objective' :'binary',
    'learning_rate' : 0.01,
    'num_boost_round':800,
    'num_leaves' : 1024,
    'metric': 'binary_logloss',
    'num_threads':8
    }


def lgbm_trainder(seed=0):
    
    X_train, X_val, Y_train, Y_val = train_test_split(
    x_train, y_train.y.values, test_size=0.2, random_state=seed)
    
    d_train = lgb.Dataset(X_train, label=Y_train)
    d_valid = lgb.Dataset(X_val, label=Y_val)
    
    def lgb_f1_score(y_hat, data):
        y_true = data.get_label()
        y_hat = np.round(y_hat) # scikits f1 doesn't like probabilities
        return 'f1', f1_score(y_true, y_hat), True
    
    #Learning
    evals_result = {}    
    params['seed']=seed
    clf = lgb.train(params, d_train,valid_sets=[d_valid], valid_names=['valid'],feval=lgb_f1_score,evals_result=evals_result)   
    lgb.plot_metric(evals_result, metric='f1')
    
    #Prediction
    target=list(clf.predict(x_test))
    
    return target, f1_score(Y_val,np.round(clf.predict(X_val)))

size = 8

city_lgbm_proba = []
city_lgbm_score = []

#s = randint(0,2**32 - 1)
#seeds = [2664668057, 2089758939, 3947519058, 3264639579, 2732337498, 3112659518, 777795139, 4251120304]
seeds = [1826919449, 3594573189, 3932881803, 1789788218, 2664093170, 3512297515, 2977255468, 2942558705]

for s in seeds:
    proba, score = lgbm_trainder(seed=s)
    city_lgbm_proba.append(proba)
    city_lgbm_score.append(score)
# Out:
# D:\Anaconda\lib\site-packages\lightgbm\engine.py:113: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# D:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [1]	valid's binary_logloss: 0.600913	valid's f1: 0
# [2]	valid's binary_logloss: 0.59295	valid's f1: 0
# [3]	valid's binary_logloss: 0.585199	valid's f1: 0
# [4]	valid's binary_logloss: 0.577638	valid's f1: 0
# [5]	valid's binary_logloss: 0.570269	valid's f1: 0
# [6]	valid's binary_logloss: 0.563089	valid's f1: 0
# [7]	valid's binary_logloss: 0.556073	valid's f1: 0
# [8]	valid's binary_logloss: 0.54923	valid's f1: 0
# [9]	valid's binary_logloss: 0.542546	valid's f1: 0
# [10]	valid's binary_logloss: 0.536013	valid's f1: 0
# [11]	valid's binary_logloss: 0.529623	valid's f1: 0
# [12]	valid's binary_logloss: 0.523376	valid's f1: 0
# [13]	valid's binary_logloss: 0.51727	valid's f1: 0
# [14]	valid's binary_logloss: 0.511294	valid's f1: 0
# [15]	valid's binary_logloss: 0.505444	valid's f1: 0
# [16]	valid's binary_logloss: 0.499727	valid's f1: 0
# [17]	valid's binary_logloss: 0.494122	valid's f1: 0
# [18]	valid's binary_logloss: 0.488638	valid's f1: 0
# [19]	valid's binary_logloss: 0.48325	valid's f1: 0
# [20]	valid's binary_logloss: 0.477975	valid's f1: 0
# [21]	valid's binary_logloss: 0.472798	valid's f1: 0
# [22]	valid's binary_logloss: 0.467725	valid's f1: 0
# [23]	valid's binary_logloss: 0.462754	valid's f1: 0
# [24]	valid's binary_logloss: 0.457877	valid's f1: 0
# [25]	valid's binary_logloss: 0.453085	valid's f1: 0
# [26]	valid's binary_logloss: 0.448386	valid's f1: 0
# [27]	valid's binary_logloss: 0.443777	valid's f1: 0
# [28]	valid's binary_logloss: 0.439252	valid's f1: 0
# [29]	valid's binary_logloss: 0.434811	valid's f1: 0
# [30]	valid's binary_logloss: 0.430439	valid's f1: 0
# [31]	valid's binary_logloss: 0.426152	valid's f1: 0
# [32]	valid's binary_logloss: 0.421939	valid's f1: 0
# [33]	valid's binary_logloss: 0.417804	valid's f1: 0
# [34]	valid's binary_logloss: 0.413737	valid's f1: 0.693141
# [35]	valid's binary_logloss: 0.40974	valid's f1: 0.762319
# [36]	valid's binary_logloss: 0.405802	valid's f1: 0.794827
# [37]	valid's binary_logloss: 0.401943	valid's f1: 0.818191
# [38]	valid's binary_logloss: 0.398136	valid's f1: 0.828019
# [39]	valid's binary_logloss: 0.394392	valid's f1: 0.839686
# [40]	valid's binary_logloss: 0.390715	valid's f1: 0.852184
# [41]	valid's binary_logloss: 0.3871	valid's f1: 0.858741
# [42]	valid's binary_logloss: 0.383557	valid's f1: 0.864764
# [43]	valid's binary_logloss: 0.380076	valid's f1: 0.868984
# [44]	valid's binary_logloss: 0.376643	valid's f1: 0.873337
# [45]	valid's binary_logloss: 0.37327	valid's f1: 0.87629
# [46]	valid's binary_logloss: 0.36995	valid's f1: 0.878361
# [47]	valid's binary_logloss: 0.366675	valid's f1: 0.880705
# [48]	valid's binary_logloss: 0.363455	valid's f1: 0.882533
# [49]	valid's binary_logloss: 0.360284	valid's f1: 0.88443
# [50]	valid's binary_logloss: 0.357161	valid's f1: 0.886101
# [51]	valid's binary_logloss: 0.354092	valid's f1: 0.887591
# [52]	valid's binary_logloss: 0.351065	valid's f1: 0.889232
# [53]	valid's binary_logloss: 0.348091	valid's f1: 0.890682
# [54]	valid's binary_logloss: 0.345154	valid's f1: 0.892018
# [55]	valid's binary_logloss: 0.342268	valid's f1: 0.89312
# [56]	valid's binary_logloss: 0.339419	valid's f1: 0.894249
# [57]	valid's binary_logloss: 0.336619	valid's f1: 0.895118
# [58]	valid's binary_logloss: 0.333858	valid's f1: 0.896168
# [59]	valid's binary_logloss: 0.331135	valid's f1: 0.897226
# [60]	valid's binary_logloss: 0.328451	valid's f1: 0.897929
# [61]	valid's binary_logloss: 0.325807	valid's f1: 0.898913
# [62]	valid's binary_logloss: 0.323198	valid's f1: 0.899642
# [63]	valid's binary_logloss: 0.320626	valid's f1: 0.900306
# [64]	valid's binary_logloss: 0.318092	valid's f1: 0.900978
# [65]	valid's binary_logloss: 0.315595	valid's f1: 0.901631
# [66]	valid's binary_logloss: 0.313124	valid's f1: 0.902238
# [67]	valid's binary_logloss: 0.310694	valid's f1: 0.902848
# [68]	valid's binary_logloss: 0.308298	valid's f1: 0.903403
# [69]	valid's binary_logloss: 0.305934	valid's f1: 0.903746
# [70]	valid's binary_logloss: 0.303602	valid's f1: 0.904164
# [71]	valid's binary_logloss: 0.301309	valid's f1: 0.904526
# [72]	valid's binary_logloss: 0.299045	valid's f1: 0.904809
# [73]	valid's binary_logloss: 0.296817	valid's f1: 0.905272
# [74]	valid's binary_logloss: 0.294619	valid's f1: 0.90567
# [75]	valid's binary_logloss: 0.292452	valid's f1: 0.906035
# [76]	valid's binary_logloss: 0.290315	valid's f1: 0.906452
# [77]	valid's binary_logloss: 0.288203	valid's f1: 0.906823
# [78]	valid's binary_logloss: 0.286124	valid's f1: 0.907055
# [79]	valid's binary_logloss: 0.284072	valid's f1: 0.907569
# [80]	valid's binary_logloss: 0.282049	valid's f1: 0.907957
# [81]	valid's binary_logloss: 0.280053	valid's f1: 0.908206
# [82]	valid's binary_logloss: 0.278079	valid's f1: 0.908543
# [83]	valid's binary_logloss: 0.276136	valid's f1: 0.90877
# [84]	valid's binary_logloss: 0.274217	valid's f1: 0.90901
# [85]	valid's binary_logloss: 0.272327	valid's f1: 0.909174
# [86]	valid's binary_logloss: 0.270455	valid's f1: 0.9094
# [87]	valid's binary_logloss: 0.268611	valid's f1: 0.909752
# [88]	valid's binary_logloss: 0.26679	valid's f1: 0.910082
# [89]	valid's binary_logloss: 0.264995	valid's f1: 0.91027
# [90]	valid's binary_logloss: 0.263227	valid's f1: 0.910456
# [91]	valid's binary_logloss: 0.26148	valid's f1: 0.910494
# [92]	valid's binary_logloss: 0.259754	valid's f1: 0.910738
# [93]	valid's binary_logloss: 0.258055	valid's f1: 0.910952
# [94]	valid's binary_logloss: 0.25638	valid's f1: 0.911158
# [95]	valid's binary_logloss: 0.254719	valid's f1: 0.91131
# [96]	valid's binary_logloss: 0.253078	valid's f1: 0.911461
# [97]	valid's binary_logloss: 0.251456	valid's f1: 0.911649
# [98]	valid's binary_logloss: 0.249861	valid's f1: 0.911886
# [99]	valid's binary_logloss: 0.248285	valid's f1: 0.911893
# [100]	valid's binary_logloss: 0.246725	valid's f1: 0.91218
# [101]	valid's binary_logloss: 0.245183	valid's f1: 0.912291
# [102]	valid's binary_logloss: 0.243662	valid's f1: 0.912438
# [103]	valid's binary_logloss: 0.242155	valid's f1: 0.912597
# [104]	valid's binary_logloss: 0.240677	valid's f1: 0.912702
# [105]	valid's binary_logloss: 0.23921	valid's f1: 0.912869
# [106]	valid's binary_logloss: 0.237762	valid's f1: 0.91309
# [107]	valid's binary_logloss: 0.236339	valid's f1: 0.913205
# [108]	valid's binary_logloss: 0.234929	valid's f1: 0.913307
# [109]	valid's binary_logloss: 0.233537	valid's f1: 0.913414
# [110]	valid's binary_logloss: 0.232165	valid's f1: 0.913493
# [111]	valid's binary_logloss: 0.230808	valid's f1: 0.91358
# [112]	valid's binary_logloss: 0.229469	valid's f1: 0.913765
# [113]	valid's binary_logloss: 0.228145	valid's f1: 0.913863
# [114]	valid's binary_logloss: 0.226838	valid's f1: 0.913844
# [115]	valid's binary_logloss: 0.225545	valid's f1: 0.914022
# [116]	valid's binary_logloss: 0.22427	valid's f1: 0.914064
# [117]	valid's binary_logloss: 0.223012	valid's f1: 0.914139
# [118]	valid's binary_logloss: 0.221773	valid's f1: 0.91417
# [119]	valid's binary_logloss: 0.220542	valid's f1: 0.914259
# [120]	valid's binary_logloss: 0.219332	valid's f1: 0.914391
# [121]	valid's binary_logloss: 0.218132	valid's f1: 0.914499
# [122]	valid's binary_logloss: 0.216953	valid's f1: 0.914519
# [123]	valid's binary_logloss: 0.215781	valid's f1: 0.914541
# [124]	valid's binary_logloss: 0.214627	valid's f1: 0.914606
# [125]	valid's binary_logloss: 0.213484	valid's f1: 0.914707
# [126]	valid's binary_logloss: 0.212359	valid's f1: 0.914669
# [127]	valid's binary_logloss: 0.211246	valid's f1: 0.914771
# [128]	valid's binary_logloss: 0.210147	valid's f1: 0.914861
# [129]	valid's binary_logloss: 0.20906	valid's f1: 0.915013
# [130]	valid's binary_logloss: 0.207984	valid's f1: 0.915105
# [131]	valid's binary_logloss: 0.206924	valid's f1: 0.915257
# [132]	valid's binary_logloss: 0.205875	valid's f1: 0.915249
# [133]	valid's binary_logloss: 0.204843	valid's f1: 0.915376
# [134]	valid's binary_logloss: 0.203818	valid's f1: 0.915469
# [135]	valid's binary_logloss: 0.202805	valid's f1: 0.915533
# [136]	valid's binary_logloss: 0.201802	valid's f1: 0.915541
# [137]	valid's binary_logloss: 0.200818	valid's f1: 0.915713
# [138]	valid's binary_logloss: 0.199847	valid's f1: 0.915716
# [139]	valid's binary_logloss: 0.19888	valid's f1: 0.915907
# [140]	valid's binary_logloss: 0.19793	valid's f1: 0.915921
# [141]	valid's binary_logloss: 0.196986	valid's f1: 0.915977
# [142]	valid's binary_logloss: 0.196048	valid's f1: 0.915977
# [143]	valid's binary_logloss: 0.195122	valid's f1: 0.916059
# [144]	valid's binary_logloss: 0.194207	valid's f1: 0.916004
# [145]	valid's binary_logloss: 0.193302	valid's f1: 0.916062
# [146]	valid's binary_logloss: 0.19241	valid's f1: 0.916127
# [147]	valid's binary_logloss: 0.191529	valid's f1: 0.916135
# [148]	valid's binary_logloss: 0.190661	valid's f1: 0.9162
# [149]	valid's binary_logloss: 0.1898	valid's f1: 0.916236
# [150]	valid's binary_logloss: 0.188946	valid's f1: 0.916302
# [151]	valid's binary_logloss: 0.188109	valid's f1: 0.916298
# [152]	valid's binary_logloss: 0.187279	valid's f1: 0.916365
# [153]	valid's binary_logloss: 0.186456	valid's f1: 0.916429
# [154]	valid's binary_logloss: 0.18564	valid's f1: 0.916445
# [155]	valid's binary_logloss: 0.184839	valid's f1: 0.916508
# [156]	valid's binary_logloss: 0.184043	valid's f1: 0.916512
# [157]	valid's binary_logloss: 0.183256	valid's f1: 0.916524
# [158]	valid's binary_logloss: 0.182481	valid's f1: 0.916572
# [159]	valid's binary_logloss: 0.181712	valid's f1: 0.916643
# [160]	valid's binary_logloss: 0.180948	valid's f1: 0.916661
# [161]	valid's binary_logloss: 0.180203	valid's f1: 0.916686
# [162]	valid's binary_logloss: 0.179463	valid's f1: 0.916745
# [163]	valid's binary_logloss: 0.178728	valid's f1: 0.916734
# [164]	valid's binary_logloss: 0.178006	valid's f1: 0.916765
# [165]	valid's binary_logloss: 0.17729	valid's f1: 0.91674
# [166]	valid's binary_logloss: 0.176587	valid's f1: 0.916801
# [167]	valid's binary_logloss: 0.175887	valid's f1: 0.916769
# [168]	valid's binary_logloss: 0.175198	valid's f1: 0.916809
# [169]	valid's binary_logloss: 0.174515	valid's f1: 0.916851
# [170]	valid's binary_logloss: 0.173843	valid's f1: 0.916852
# [171]	valid's binary_logloss: 0.17318	valid's f1: 0.916875
# [172]	valid's binary_logloss: 0.172524	valid's f1: 0.916908
# [173]	valid's binary_logloss: 0.171871	valid's f1: 0.916935
# [174]	valid's binary_logloss: 0.171227	valid's f1: 0.916977
# [175]	valid's binary_logloss: 0.170592	valid's f1: 0.916962
# [176]	valid's binary_logloss: 0.169953	valid's f1: 0.917019
# [177]	valid's binary_logloss: 0.169319	valid's f1: 0.917098
# [178]	valid's binary_logloss: 0.168694	valid's f1: 0.917068
# [179]	valid's binary_logloss: 0.168076	valid's f1: 0.917023
# [180]	valid's binary_logloss: 0.167463	valid's f1: 0.917097
# [181]	valid's binary_logloss: 0.166856	valid's f1: 0.917114
# [182]	valid's binary_logloss: 0.166259	valid's f1: 0.917143
# [183]	valid's binary_logloss: 0.165672	valid's f1: 0.917161
# [184]	valid's binary_logloss: 0.16509	valid's f1: 0.917235
# [185]	valid's binary_logloss: 0.164519	valid's f1: 0.917228
# [186]	valid's binary_logloss: 0.163951	valid's f1: 0.91727
# [187]	valid's binary_logloss: 0.163374	valid's f1: 0.917229
# [188]	valid's binary_logloss: 0.162814	valid's f1: 0.917205
# [189]	valid's binary_logloss: 0.162268	valid's f1: 0.91725
# [190]	valid's binary_logloss: 0.161713	valid's f1: 0.917232
# [191]	valid's binary_logloss: 0.161164	valid's f1: 0.917263
# [192]	valid's binary_logloss: 0.160636	valid's f1: 0.917257
# [193]	valid's binary_logloss: 0.160094	valid's f1: 0.917303
# [194]	valid's binary_logloss: 0.159576	valid's f1: 0.917335
# [195]	valid's binary_logloss: 0.159046	valid's f1: 0.917344
# [196]	valid's binary_logloss: 0.158536	valid's f1: 0.917309
# [197]	valid's binary_logloss: 0.158014	valid's f1: 0.917331
# [198]	valid's binary_logloss: 0.15752	valid's f1: 0.91735
# [199]	valid's binary_logloss: 0.157014	valid's f1: 0.917395
# [200]	valid's binary_logloss: 0.156525	valid's f1: 0.917366
# [201]	valid's binary_logloss: 0.156028	valid's f1: 0.917417
# [202]	valid's binary_logloss: 0.155555	valid's f1: 0.917338
# [203]	valid's binary_logloss: 0.155074	valid's f1: 0.917367
# [204]	valid's binary_logloss: 0.154607	valid's f1: 0.917515
# [205]	valid's binary_logloss: 0.154137	valid's f1: 0.917574
# [206]	valid's binary_logloss: 0.15368	valid's f1: 0.917579
# [207]	valid's binary_logloss: 0.153232	valid's f1: 0.917547
# [208]	valid's binary_logloss: 0.152779	valid's f1: 0.917554
# [209]	valid's binary_logloss: 0.152335	valid's f1: 0.917595
# [210]	valid's binary_logloss: 0.151892	valid's f1: 0.917611
# [211]	valid's binary_logloss: 0.151463	valid's f1: 0.917649
# [212]	valid's binary_logloss: 0.15104	valid's f1: 0.917662
# [213]	valid's binary_logloss: 0.150621	valid's f1: 0.917657
# [214]	valid's binary_logloss: 0.150209	valid's f1: 0.917672
# [215]	valid's binary_logloss: 0.149799	valid's f1: 0.917671
# [216]	valid's binary_logloss: 0.149396	valid's f1: 0.917697
# [217]	valid's binary_logloss: 0.148984	valid's f1: 0.9177
# [218]	valid's binary_logloss: 0.148584	valid's f1: 0.917685
# [219]	valid's binary_logloss: 0.148175	valid's f1: 0.91766
# [220]	valid's binary_logloss: 0.147774	valid's f1: 0.917667
# [221]	valid's binary_logloss: 0.14739	valid's f1: 0.917611
# [222]	valid's binary_logloss: 0.14701	valid's f1: 0.917582
# [223]	valid's binary_logloss: 0.146619	valid's f1: 0.917639
# [224]	valid's binary_logloss: 0.146234	valid's f1: 0.91767
# [225]	valid's binary_logloss: 0.145867	valid's f1: 0.917734
# [226]	valid's binary_logloss: 0.145507	valid's f1: 0.917747
# [227]	valid's binary_logloss: 0.145134	valid's f1: 0.917748
# [228]	valid's binary_logloss: 0.144783	valid's f1: 0.917765
# [229]	valid's binary_logloss: 0.144435	valid's f1: 0.917778
# [230]	valid's binary_logloss: 0.144072	valid's f1: 0.917907
# [231]	valid's binary_logloss: 0.143718	valid's f1: 0.917928
# [232]	valid's binary_logloss: 0.14338	valid's f1: 0.917986
# [233]	valid's binary_logloss: 0.143025	valid's f1: 0.917945
# [234]	valid's binary_logloss: 0.142695	valid's f1: 0.917933
# [235]	valid's binary_logloss: 0.142365	valid's f1: 0.918017
# [236]	valid's binary_logloss: 0.142028	valid's f1: 0.918014
# [237]	valid's binary_logloss: 0.141693	valid's f1: 0.918097
# [238]	valid's binary_logloss: 0.141372	valid's f1: 0.918111
# [239]	valid's binary_logloss: 0.141044	valid's f1: 0.918134
# [240]	valid's binary_logloss: 0.140733	valid's f1: 0.918232
# [241]	valid's binary_logloss: 0.140408	valid's f1: 0.918172
# [242]	valid's binary_logloss: 0.140102	valid's f1: 0.9182
# [243]	valid's binary_logloss: 0.139787	valid's f1: 0.918139
# [244]	valid's binary_logloss: 0.139493	valid's f1: 0.91817
# [245]	valid's binary_logloss: 0.13918	valid's f1: 0.918202
# [246]	valid's binary_logloss: 0.138888	valid's f1: 0.918237
# [247]	valid's binary_logloss: 0.138587	valid's f1: 0.918204
# [248]	valid's binary_logloss: 0.138307	valid's f1: 0.918275
# [249]	valid's binary_logloss: 0.138007	valid's f1: 0.918241
# [250]	valid's binary_logloss: 0.137717	valid's f1: 0.918241
# [251]	valid's binary_logloss: 0.13744	valid's f1: 0.918214
# [252]	valid's binary_logloss: 0.137166	valid's f1: 0.918222
# [253]	valid's binary_logloss: 0.136895	valid's f1: 0.918205
# [254]	valid's binary_logloss: 0.136612	valid's f1: 0.918219
# [255]	valid's binary_logloss: 0.136335	valid's f1: 0.918187
# [256]	valid's binary_logloss: 0.13606	valid's f1: 0.918206
# [257]	valid's binary_logloss: 0.135788	valid's f1: 0.918208
# [258]	valid's binary_logloss: 0.135525	valid's f1: 0.918223
# [259]	valid's binary_logloss: 0.13526	valid's f1: 0.91826
# [260]	valid's binary_logloss: 0.134994	valid's f1: 0.918202
# [261]	valid's binary_logloss: 0.134742	valid's f1: 0.918256
# [262]	valid's binary_logloss: 0.134489	valid's f1: 0.918303
# [263]	valid's binary_logloss: 0.134231	valid's f1: 0.918304
# [264]	valid's binary_logloss: 0.133976	valid's f1: 0.918358
# [265]	valid's binary_logloss: 0.133732	valid's f1: 0.918341
# [266]	valid's binary_logloss: 0.133486	valid's f1: 0.918369
# [267]	valid's binary_logloss: 0.133252	valid's f1: 0.918345
# [268]	valid's binary_logloss: 0.13302	valid's f1: 0.918406
# [269]	valid's binary_logloss: 0.132785	valid's f1: 0.918436
# [270]	valid's binary_logloss: 0.132556	valid's f1: 0.918435
# [271]	valid's binary_logloss: 0.132331	valid's f1: 0.918476
# [272]	valid's binary_logloss: 0.132107	valid's f1: 0.918468
# [273]	valid's binary_logloss: 0.131884	valid's f1: 0.918437
# [274]	valid's binary_logloss: 0.131665	valid's f1: 0.918413
# [275]	valid's binary_logloss: 0.13145	valid's f1: 0.918439
# [276]	valid's binary_logloss: 0.13123	valid's f1: 0.918421
# [277]	valid's binary_logloss: 0.131012	valid's f1: 0.918355
# [278]	valid's binary_logloss: 0.130798	valid's f1: 0.918386
# [279]	valid's binary_logloss: 0.130588	valid's f1: 0.918432
# [280]	valid's binary_logloss: 0.130377	valid's f1: 0.918392
# [281]	valid's binary_logloss: 0.130173	valid's f1: 0.91838
# [282]	valid's binary_logloss: 0.129969	valid's f1: 0.918384
# [283]	valid's binary_logloss: 0.12977	valid's f1: 0.918377
# [284]	valid's binary_logloss: 0.129562	valid's f1: 0.918432
# [285]	valid's binary_logloss: 0.129361	valid's f1: 0.918435
# [286]	valid's binary_logloss: 0.129167	valid's f1: 0.918418
# [287]	valid's binary_logloss: 0.128971	valid's f1: 0.918421
# [288]	valid's binary_logloss: 0.128777	valid's f1: 0.918391
# [289]	valid's binary_logloss: 0.128588	valid's f1: 0.918377
# [290]	valid's binary_logloss: 0.128397	valid's f1: 0.918413
# [291]	valid's binary_logloss: 0.12821	valid's f1: 0.918426
# [292]	valid's binary_logloss: 0.128024	valid's f1: 0.918426
# [293]	valid's binary_logloss: 0.127838	valid's f1: 0.918447
# [294]	valid's binary_logloss: 0.127655	valid's f1: 0.918449
# [295]	valid's binary_logloss: 0.127476	valid's f1: 0.918443
# [296]	valid's binary_logloss: 0.127297	valid's f1: 0.918479
# [297]	valid's binary_logloss: 0.127122	valid's f1: 0.918554
# [298]	valid's binary_logloss: 0.126946	valid's f1: 0.918582
# [299]	valid's binary_logloss: 0.126774	valid's f1: 0.918631
# [300]	valid's binary_logloss: 0.126604	valid's f1: 0.918599
# [301]	valid's binary_logloss: 0.126439	valid's f1: 0.918588
# [302]	valid's binary_logloss: 0.126275	valid's f1: 0.918628
# [303]	valid's binary_logloss: 0.126107	valid's f1: 0.918626
# [304]	valid's binary_logloss: 0.125952	valid's f1: 0.918619
# [305]	valid's binary_logloss: 0.12579	valid's f1: 0.918665
# [306]	valid's binary_logloss: 0.125628	valid's f1: 0.918648
# [307]	valid's binary_logloss: 0.125467	valid's f1: 0.918617
# [308]	valid's binary_logloss: 0.125316	valid's f1: 0.918677
# [309]	valid's binary_logloss: 0.125162	valid's f1: 0.918676
# [310]	valid's binary_logloss: 0.125007	valid's f1: 0.918711
# [311]	valid's binary_logloss: 0.124854	valid's f1: 0.918728
# [312]	valid's binary_logloss: 0.124703	valid's f1: 0.918704
# [313]	valid's binary_logloss: 0.124559	valid's f1: 0.918715
# [314]	valid's binary_logloss: 0.124409	valid's f1: 0.918734
# [315]	valid's binary_logloss: 0.124261	valid's f1: 0.91877
# [316]	valid's binary_logloss: 0.124111	valid's f1: 0.918718
# [317]	valid's binary_logloss: 0.123966	valid's f1: 0.918711
# [318]	valid's binary_logloss: 0.123829	valid's f1: 0.918798
# [319]	valid's binary_logloss: 0.123682	valid's f1: 0.918841
# [320]	valid's binary_logloss: 0.123545	valid's f1: 0.918798
# [321]	valid's binary_logloss: 0.12341	valid's f1: 0.918824
# [322]	valid's binary_logloss: 0.123269	valid's f1: 0.918882
# [323]	valid's binary_logloss: 0.123135	valid's f1: 0.918876
# [324]	valid's binary_logloss: 0.123001	valid's f1: 0.918896
# [325]	valid's binary_logloss: 0.122869	valid's f1: 0.918923
# [326]	valid's binary_logloss: 0.122744	valid's f1: 0.918931
# [327]	valid's binary_logloss: 0.122611	valid's f1: 0.918895
# [328]	valid's binary_logloss: 0.122479	valid's f1: 0.918919
# [329]	valid's binary_logloss: 0.122343	valid's f1: 0.91886
# [330]	valid's binary_logloss: 0.122214	valid's f1: 0.918927
# [331]	valid's binary_logloss: 0.122088	valid's f1: 0.918866
# [332]	valid's binary_logloss: 0.121965	valid's f1: 0.91881
# [333]	valid's binary_logloss: 0.121841	valid's f1: 0.918806
# [334]	valid's binary_logloss: 0.121724	valid's f1: 0.91879
# [335]	valid's binary_logloss: 0.121601	valid's f1: 0.918785
# [336]	valid's binary_logloss: 0.121484	valid's f1: 0.918777
# [337]	valid's binary_logloss: 0.121364	valid's f1: 0.918812
# [338]	valid's binary_logloss: 0.121248	valid's f1: 0.918841
# [339]	valid's binary_logloss: 0.121132	valid's f1: 0.918844
# [340]	valid's binary_logloss: 0.121017	valid's f1: 0.918845
# [341]	valid's binary_logloss: 0.120902	valid's f1: 0.918871
# [342]	valid's binary_logloss: 0.120794	valid's f1: 0.918853
# [343]	valid's binary_logloss: 0.120686	valid's f1: 0.918881
# [344]	valid's binary_logloss: 0.120573	valid's f1: 0.918924
# [345]	valid's binary_logloss: 0.12047	valid's f1: 0.918943
# [346]	valid's binary_logloss: 0.120362	valid's f1: 0.918959
# [347]	valid's binary_logloss: 0.120256	valid's f1: 0.918943
# [348]	valid's binary_logloss: 0.120144	valid's f1: 0.918962
# [349]	valid's binary_logloss: 0.120041	valid's f1: 0.918996
# [350]	valid's binary_logloss: 0.119937	valid's f1: 0.919007
# [351]	valid's binary_logloss: 0.119829	valid's f1: 0.919043
# [352]	valid's binary_logloss: 0.119729	valid's f1: 0.919053
# [353]	valid's binary_logloss: 0.119628	valid's f1: 0.919021
# [354]	valid's binary_logloss: 0.119528	valid's f1: 0.919013
# [355]	valid's binary_logloss: 0.119428	valid's f1: 0.919002
# [356]	valid's binary_logloss: 0.119334	valid's f1: 0.919018
# [357]	valid's binary_logloss: 0.119236	valid's f1: 0.919079
# [358]	valid's binary_logloss: 0.119136	valid's f1: 0.919053
# [359]	valid's binary_logloss: 0.119033	valid's f1: 0.919019
# [360]	valid's binary_logloss: 0.11894	valid's f1: 0.919025
# [361]	valid's binary_logloss: 0.118839	valid's f1: 0.919036
# [362]	valid's binary_logloss: 0.118747	valid's f1: 0.919058
# [363]	valid's binary_logloss: 0.118646	valid's f1: 0.919055
# [364]	valid's binary_logloss: 0.118552	valid's f1: 0.919037
# [365]	valid's binary_logloss: 0.118464	valid's f1: 0.919061
# [366]	valid's binary_logloss: 0.118381	valid's f1: 0.919
# [367]	valid's binary_logloss: 0.118286	valid's f1: 0.919012
# [368]	valid's binary_logloss: 0.118196	valid's f1: 0.919025
# [369]	valid's binary_logloss: 0.118104	valid's f1: 0.919001
# [370]	valid's binary_logloss: 0.118019	valid's f1: 0.918992
# [371]	valid's binary_logloss: 0.11793	valid's f1: 0.919019
# [372]	valid's binary_logloss: 0.117842	valid's f1: 0.919031
# [373]	valid's binary_logloss: 0.117766	valid's f1: 0.918996
# [374]	valid's binary_logloss: 0.117679	valid's f1: 0.919019
# [375]	valid's binary_logloss: 0.117601	valid's f1: 0.919024
# [376]	valid's binary_logloss: 0.117515	valid's f1: 0.919071
# [377]	valid's binary_logloss: 0.117427	valid's f1: 0.919064
# [378]	valid's binary_logloss: 0.117352	valid's f1: 0.919096
# [379]	valid's binary_logloss: 0.11727	valid's f1: 0.91915
# [380]	valid's binary_logloss: 0.117186	valid's f1: 0.919134
# [381]	valid's binary_logloss: 0.117109	valid's f1: 0.919152
# [382]	valid's binary_logloss: 0.117025	valid's f1: 0.919201
# [383]	valid's binary_logloss: 0.116952	valid's f1: 0.91918
# [384]	valid's binary_logloss: 0.116868	valid's f1: 0.919172
# [385]	valid's binary_logloss: 0.116789	valid's f1: 0.919162
# [386]	valid's binary_logloss: 0.116718	valid's f1: 0.919194
# [387]	valid's binary_logloss: 0.116653	valid's f1: 0.919249
# [388]	valid's binary_logloss: 0.116573	valid's f1: 0.919269
# [389]	valid's binary_logloss: 0.116502	valid's f1: 0.91928
# [390]	valid's binary_logloss: 0.11643	valid's f1: 0.919252
# [391]	valid's binary_logloss: 0.116359	valid's f1: 0.919268
# [392]	valid's binary_logloss: 0.116286	valid's f1: 0.919273
# [393]	valid's binary_logloss: 0.116222	valid's f1: 0.919319
# [394]	valid's binary_logloss: 0.11615	valid's f1: 0.919328
# [395]	valid's binary_logloss: 0.116077	valid's f1: 0.919317
# [396]	valid's binary_logloss: 0.116012	valid's f1: 0.919313
# [397]	valid's binary_logloss: 0.11594	valid's f1: 0.919294
# [398]	valid's binary_logloss: 0.115883	valid's f1: 0.919332
# [399]	valid's binary_logloss: 0.115813	valid's f1: 0.919349
# [400]	valid's binary_logloss: 0.115747	valid's f1: 0.919351
# [401]	valid's binary_logloss: 0.115688	valid's f1: 0.919325
# [402]	valid's binary_logloss: 0.115624	valid's f1: 0.919337
# [403]	valid's binary_logloss: 0.115555	valid's f1: 0.919369
# [404]	valid's binary_logloss: 0.115489	valid's f1: 0.91938
# [405]	valid's binary_logloss: 0.115427	valid's f1: 0.919336
# [406]	valid's binary_logloss: 0.115372	valid's f1: 0.919344
# [407]	valid's binary_logloss: 0.115312	valid's f1: 0.9193
# [408]	valid's binary_logloss: 0.115261	valid's f1: 0.919312
# [409]	valid's binary_logloss: 0.115195	valid's f1: 0.919312
# [410]	valid's binary_logloss: 0.115138	valid's f1: 0.919283
# [411]	valid's binary_logloss: 0.115073	valid's f1: 0.919317
# [412]	valid's binary_logloss: 0.115014	valid's f1: 0.919276
# [413]	valid's binary_logloss: 0.114963	valid's f1: 0.919319
# [414]	valid's binary_logloss: 0.114901	valid's f1: 0.919295
# [415]	valid's binary_logloss: 0.114839	valid's f1: 0.919301
# [416]	valid's binary_logloss: 0.114785	valid's f1: 0.919276
# [417]	valid's binary_logloss: 0.114731	valid's f1: 0.919312
# [418]	valid's binary_logloss: 0.114669	valid's f1: 0.919306
# [419]	valid's binary_logloss: 0.114621	valid's f1: 0.919352
# [420]	valid's binary_logloss: 0.114562	valid's f1: 0.919359
# [421]	valid's binary_logloss: 0.114513	valid's f1: 0.91936
# [422]	valid's binary_logloss: 0.114457	valid's f1: 0.919312
# [423]	valid's binary_logloss: 0.114398	valid's f1: 0.919332
# [424]	valid's binary_logloss: 0.11435	valid's f1: 0.919342
# [425]	valid's binary_logloss: 0.114294	valid's f1: 0.919381
# [426]	valid's binary_logloss: 0.114232	valid's f1: 0.91936
# [427]	valid's binary_logloss: 0.114175	valid's f1: 0.919367
# [428]	valid's binary_logloss: 0.114121	valid's f1: 0.919361
# [429]	valid's binary_logloss: 0.114075	valid's f1: 0.919381
# [430]	valid's binary_logloss: 0.11402	valid's f1: 0.91939
# [431]	valid's binary_logloss: 0.113966	valid's f1: 0.919409
# [432]	valid's binary_logloss: 0.11391	valid's f1: 0.919442
# [433]	valid's binary_logloss: 0.113856	valid's f1: 0.919425
# [434]	valid's binary_logloss: 0.113803	valid's f1: 0.91945
# [435]	valid's binary_logloss: 0.11375	valid's f1: 0.919469
# [436]	valid's binary_logloss: 0.113698	valid's f1: 0.919433
# [437]	valid's binary_logloss: 0.113655	valid's f1: 0.919473
# [438]	valid's binary_logloss: 0.113611	valid's f1: 0.919486
# [439]	valid's binary_logloss: 0.113565	valid's f1: 0.91945
# [440]	valid's binary_logloss: 0.113511	valid's f1: 0.919452
# [441]	valid's binary_logloss: 0.113465	valid's f1: 0.919434
# [442]	valid's binary_logloss: 0.113415	valid's f1: 0.919445
# [443]	valid's binary_logloss: 0.113375	valid's f1: 0.919464
# [444]	valid's binary_logloss: 0.113328	valid's f1: 0.91948
# [445]	valid's binary_logloss: 0.11328	valid's f1: 0.919508
# [446]	valid's binary_logloss: 0.113237	valid's f1: 0.919494
# [447]	valid's binary_logloss: 0.113185	valid's f1: 0.919515
# [448]	valid's binary_logloss: 0.113146	valid's f1: 0.91954
# [449]	valid's binary_logloss: 0.113102	valid's f1: 0.91952
# [450]	valid's binary_logloss: 0.113053	valid's f1: 0.919492
# [451]	valid's binary_logloss: 0.113005	valid's f1: 0.9195
# [452]	valid's binary_logloss: 0.112963	valid's f1: 0.919529
# [453]	valid's binary_logloss: 0.112924	valid's f1: 0.919538
# [454]	valid's binary_logloss: 0.112877	valid's f1: 0.919565
# [455]	valid's binary_logloss: 0.112829	valid's f1: 0.91957
# [456]	valid's binary_logloss: 0.112789	valid's f1: 0.919573
# [457]	valid's binary_logloss: 0.112745	valid's f1: 0.919581
# [458]	valid's binary_logloss: 0.11271	valid's f1: 0.919544
# [459]	valid's binary_logloss: 0.112667	valid's f1: 0.919533
# [460]	valid's binary_logloss: 0.112629	valid's f1: 0.919574
# [461]	valid's binary_logloss: 0.112585	valid's f1: 0.919593
# [462]	valid's binary_logloss: 0.112544	valid's f1: 0.919568
# [463]	valid's binary_logloss: 0.112508	valid's f1: 0.919566
# [464]	valid's binary_logloss: 0.112476	valid's f1: 0.919583
# [465]	valid's binary_logloss: 0.112438	valid's f1: 0.919591
# [466]	valid's binary_logloss: 0.112408	valid's f1: 0.919588
# [467]	valid's binary_logloss: 0.112367	valid's f1: 0.919597
# [468]	valid's binary_logloss: 0.112329	valid's f1: 0.919622
# [469]	valid's binary_logloss: 0.112296	valid's f1: 0.91968
# [470]	valid's binary_logloss: 0.112257	valid's f1: 0.919662
# [471]	valid's binary_logloss: 0.112224	valid's f1: 0.9197
# [472]	valid's binary_logloss: 0.112187	valid's f1: 0.919673
# [473]	valid's binary_logloss: 0.112152	valid's f1: 0.919696
# [474]	valid's binary_logloss: 0.112123	valid's f1: 0.919668
# [475]	valid's binary_logloss: 0.11209	valid's f1: 0.91963
# [476]	valid's binary_logloss: 0.112052	valid's f1: 0.919614
# [477]	valid's binary_logloss: 0.112015	valid's f1: 0.919614
# [478]	valid's binary_logloss: 0.111983	valid's f1: 0.919664
# [479]	valid's binary_logloss: 0.111942	valid's f1: 0.919647
# [480]	valid's binary_logloss: 0.11191	valid's f1: 0.919609
# [481]	valid's binary_logloss: 0.111881	valid's f1: 0.919614
# [482]	valid's binary_logloss: 0.111852	valid's f1: 0.919601
# [483]	valid's binary_logloss: 0.111824	valid's f1: 0.919653
# [484]	valid's binary_logloss: 0.111788	valid's f1: 0.919637
# [485]	valid's binary_logloss: 0.111759	valid's f1: 0.919595
# [486]	valid's binary_logloss: 0.111734	valid's f1: 0.919608
# [487]	valid's binary_logloss: 0.111706	valid's f1: 0.919633
# [488]	valid's binary_logloss: 0.111672	valid's f1: 0.919605
# [489]	valid's binary_logloss: 0.111645	valid's f1: 0.91963
# [490]	valid's binary_logloss: 0.111614	valid's f1: 0.919656
# [491]	valid's binary_logloss: 0.11159	valid's f1: 0.91967
# [492]	valid's binary_logloss: 0.111566	valid's f1: 0.919688
# [493]	valid's binary_logloss: 0.111541	valid's f1: 0.919689
# [494]	valid's binary_logloss: 0.111518	valid's f1: 0.919633
# [495]	valid's binary_logloss: 0.111494	valid's f1: 0.919636
# [496]	valid's binary_logloss: 0.111471	valid's f1: 0.919681
# [497]	valid's binary_logloss: 0.111446	valid's f1: 0.919605
# [498]	valid's binary_logloss: 0.111422	valid's f1: 0.919648
# [499]	valid's binary_logloss: 0.111402	valid's f1: 0.919642
# [500]	valid's binary_logloss: 0.111381	valid's f1: 0.919636
# [501]	valid's binary_logloss: 0.111358	valid's f1: 0.919658
# [502]	valid's binary_logloss: 0.11134	valid's f1: 0.919697
# [503]	valid's binary_logloss: 0.111321	valid's f1: 0.919682
# [504]	valid's binary_logloss: 0.111296	valid's f1: 0.919681
# [505]	valid's binary_logloss: 0.111277	valid's f1: 0.919716
# [506]	valid's binary_logloss: 0.111256	valid's f1: 0.919721
# [507]	valid's binary_logloss: 0.11123	valid's f1: 0.91974
# [508]	valid's binary_logloss: 0.111209	valid's f1: 0.919729
# [509]	valid's binary_logloss: 0.11118	valid's f1: 0.919757
# [510]	valid's binary_logloss: 0.111162	valid's f1: 0.919751
# [511]	valid's binary_logloss: 0.111137	valid's f1: 0.919783
# [512]	valid's binary_logloss: 0.111109	valid's f1: 0.919806
# [513]	valid's binary_logloss: 0.11109	valid's f1: 0.919744
# [514]	valid's binary_logloss: 0.111064	valid's f1: 0.919751
# [515]	valid's binary_logloss: 0.111043	valid's f1: 0.919752
# [516]	valid's binary_logloss: 0.111019	valid's f1: 0.919724
# [517]	valid's binary_logloss: 0.110985	valid's f1: 0.919744
# [518]	valid's binary_logloss: 0.110961	valid's f1: 0.919755
# [519]	valid's binary_logloss: 0.110921	valid's f1: 0.919728
# [520]	valid's binary_logloss: 0.110891	valid's f1: 0.919769
# [521]	valid's binary_logloss: 0.110862	valid's f1: 0.919761
# [522]	valid's binary_logloss: 0.110837	valid's f1: 0.919787
# [523]	valid's binary_logloss: 0.110801	valid's f1: 0.919795
# [524]	valid's binary_logloss: 0.110786	valid's f1: 0.919803
# [525]	valid's binary_logloss: 0.110754	valid's f1: 0.919831
# [526]	valid's binary_logloss: 0.110732	valid's f1: 0.919773
# [527]	valid's binary_logloss: 0.110706	valid's f1: 0.919743
# [528]	valid's binary_logloss: 0.110682	valid's f1: 0.919805
# [529]	valid's binary_logloss: 0.110648	valid's f1: 0.919863
# [530]	valid's binary_logloss: 0.110633	valid's f1: 0.919848
# [531]	valid's binary_logloss: 0.110602	valid's f1: 0.919863
# [532]	valid's binary_logloss: 0.110587	valid's f1: 0.919832
# [533]	valid's binary_logloss: 0.110553	valid's f1: 0.919859
# [534]	valid's binary_logloss: 0.110534	valid's f1: 0.919833
# [535]	valid's binary_logloss: 0.110519	valid's f1: 0.919879
# [536]	valid's binary_logloss: 0.110492	valid's f1: 0.919912
# [537]	valid's binary_logloss: 0.110468	valid's f1: 0.919911
# [538]	valid's binary_logloss: 0.110446	valid's f1: 0.919875
# [539]	valid's binary_logloss: 0.110414	valid's f1: 0.91992
# [540]	valid's binary_logloss: 0.110394	valid's f1: 0.91995
# [541]	valid's binary_logloss: 0.11038	valid's f1: 0.919942
# [542]	valid's binary_logloss: 0.110359	valid's f1: 0.919972
# [543]	valid's binary_logloss: 0.110332	valid's f1: 0.919954
# [544]	valid's binary_logloss: 0.110317	valid's f1: 0.919951
# [545]	valid's binary_logloss: 0.110302	valid's f1: 0.919968
# [546]	valid's binary_logloss: 0.110273	valid's f1: 0.919984
# [547]	valid's binary_logloss: 0.110249	valid's f1: 0.919978
# [548]	valid's binary_logloss: 0.110227	valid's f1: 0.919989
# [549]	valid's binary_logloss: 0.110213	valid's f1: 0.919958
# [550]	valid's binary_logloss: 0.110187	valid's f1: 0.91993
# [551]	valid's binary_logloss: 0.11017	valid's f1: 0.919938
# [552]	valid's binary_logloss: 0.110155	valid's f1: 0.920049
# [553]	valid's binary_logloss: 0.110139	valid's f1: 0.920026
# [554]	valid's binary_logloss: 0.11012	valid's f1: 0.920007
# [555]	valid's binary_logloss: 0.110106	valid's f1: 0.920087
# [556]	valid's binary_logloss: 0.110083	valid's f1: 0.920087
# [557]	valid's binary_logloss: 0.110073	valid's f1: 0.920127
# [558]	valid's binary_logloss: 0.110062	valid's f1: 0.920098
# [559]	valid's binary_logloss: 0.110047	valid's f1: 0.920071
# [560]	valid's binary_logloss: 0.11003	valid's f1: 0.920087
# [561]	valid's binary_logloss: 0.110016	valid's f1: 0.920054
# [562]	valid's binary_logloss: 0.110001	valid's f1: 0.920045
# [563]	valid's binary_logloss: 0.109984	valid's f1: 0.920054
# [564]	valid's binary_logloss: 0.109971	valid's f1: 0.920046
# [565]	valid's binary_logloss: 0.109959	valid's f1: 0.920013
# [566]	valid's binary_logloss: 0.109937	valid's f1: 0.920047
# [567]	valid's binary_logloss: 0.109921	valid's f1: 0.920047
# [568]	valid's binary_logloss: 0.109914	valid's f1: 0.91998
# [569]	valid's binary_logloss: 0.109889	valid's f1: 0.91997
# [570]	valid's binary_logloss: 0.109877	valid's f1: 0.919953
# [571]	valid's binary_logloss: 0.109862	valid's f1: 0.919953
# [572]	valid's binary_logloss: 0.109841	valid's f1: 0.919972
# [573]	valid's binary_logloss: 0.109828	valid's f1: 0.91997
# [574]	valid's binary_logloss: 0.109819	valid's f1: 0.919978
# [575]	valid's binary_logloss: 0.109801	valid's f1: 0.919977
# [576]	valid's binary_logloss: 0.109791	valid's f1: 0.920022
# [577]	valid's binary_logloss: 0.109776	valid's f1: 0.920055
# [578]	valid's binary_logloss: 0.109762	valid's f1: 0.920054
# [579]	valid's binary_logloss: 0.10975	valid's f1: 0.920097
# [580]	valid's binary_logloss: 0.109734	valid's f1: 0.920141
# [581]	valid's binary_logloss: 0.109711	valid's f1: 0.920141
# [582]	valid's binary_logloss: 0.109699	valid's f1: 0.920071
# [583]	valid's binary_logloss: 0.109679	valid's f1: 0.920055
# [584]	valid's binary_logloss: 0.109664	valid's f1: 0.919978
# [585]	valid's binary_logloss: 0.109646	valid's f1: 0.919937
# [586]	valid's binary_logloss: 0.109633	valid's f1: 0.919979
# [587]	valid's binary_logloss: 0.109619	valid's f1: 0.919987
# [588]	valid's binary_logloss: 0.10961	valid's f1: 0.919982
# [589]	valid's binary_logloss: 0.109587	valid's f1: 0.920003
# [590]	valid's binary_logloss: 0.109581	valid's f1: 0.920038
# [591]	valid's binary_logloss: 0.109571	valid's f1: 0.920029
# [592]	valid's binary_logloss: 0.109558	valid's f1: 0.920007
# [593]	valid's binary_logloss: 0.109545	valid's f1: 0.920025
# [594]	valid's binary_logloss: 0.109527	valid's f1: 0.919999
# [595]	valid's binary_logloss: 0.109516	valid's f1: 0.920026
# [596]	valid's binary_logloss: 0.109508	valid's f1: 0.920025
# [597]	valid's binary_logloss: 0.109495	valid's f1: 0.920034
# [598]	valid's binary_logloss: 0.109484	valid's f1: 0.920079
# [599]	valid's binary_logloss: 0.109469	valid's f1: 0.92007
# [600]	valid's binary_logloss: 0.109457	valid's f1: 0.920087
# [601]	valid's binary_logloss: 0.109443	valid's f1: 0.920086
# [602]	valid's binary_logloss: 0.109429	valid's f1: 0.920076
# [603]	valid's binary_logloss: 0.109419	valid's f1: 0.920115
# [604]	valid's binary_logloss: 0.109407	valid's f1: 0.920117
# [605]	valid's binary_logloss: 0.109397	valid's f1: 0.920125
# [606]	valid's binary_logloss: 0.109386	valid's f1: 0.920149
# [607]	valid's binary_logloss: 0.109378	valid's f1: 0.920193
# [608]	valid's binary_logloss: 0.109369	valid's f1: 0.920207
# [609]	valid's binary_logloss: 0.109352	valid's f1: 0.920225
# [610]	valid's binary_logloss: 0.109342	valid's f1: 0.920251
# [611]	valid's binary_logloss: 0.109331	valid's f1: 0.920241
# [612]	valid's binary_logloss: 0.109325	valid's f1: 0.920254
# [613]	valid's binary_logloss: 0.109314	valid's f1: 0.920289
# [614]	valid's binary_logloss: 0.109307	valid's f1: 0.920256
# [615]	valid's binary_logloss: 0.109298	valid's f1: 0.920309
# [616]	valid's binary_logloss: 0.109277	valid's f1: 0.920285
# [617]	valid's binary_logloss: 0.109257	valid's f1: 0.920293
# [618]	valid's binary_logloss: 0.109252	valid's f1: 0.920189
# [619]	valid's binary_logloss: 0.10924	valid's f1: 0.920128
# [620]	valid's binary_logloss: 0.10922	valid's f1: 0.920156
# [621]	valid's binary_logloss: 0.109207	valid's f1: 0.920165
# [622]	valid's binary_logloss: 0.1092	valid's f1: 0.92019
# [623]	valid's binary_logloss: 0.10919	valid's f1: 0.920182
# [624]	valid's binary_logloss: 0.109186	valid's f1: 0.920225
# [625]	valid's binary_logloss: 0.109172	valid's f1: 0.920205
# [626]	valid's binary_logloss: 0.109166	valid's f1: 0.92018
# [627]	valid's binary_logloss: 0.109153	valid's f1: 0.9202
# [628]	valid's binary_logloss: 0.109143	valid's f1: 0.920165
# [629]	valid's binary_logloss: 0.109129	valid's f1: 0.920211
# [630]	valid's binary_logloss: 0.109116	valid's f1: 0.920211
# [631]	valid's binary_logloss: 0.109107	valid's f1: 0.920203
# [632]	valid's binary_logloss: 0.109086	valid's f1: 0.920177
# [633]	valid's binary_logloss: 0.109065	valid's f1: 0.920179
# [634]	valid's binary_logloss: 0.10905	valid's f1: 0.920161
# [635]	valid's binary_logloss: 0.109038	valid's f1: 0.920192
# [636]	valid's binary_logloss: 0.109021	valid's f1: 0.920243
# [637]	valid's binary_logloss: 0.109006	valid's f1: 0.920181
# [638]	valid's binary_logloss: 0.108993	valid's f1: 0.920204
# [639]	valid's binary_logloss: 0.10898	valid's f1: 0.920196
# [640]	valid's binary_logloss: 0.108963	valid's f1: 0.920216
# [641]	valid's binary_logloss: 0.108955	valid's f1: 0.920246
# [642]	valid's binary_logloss: 0.10894	valid's f1: 0.920202
# [643]	valid's binary_logloss: 0.108936	valid's f1: 0.920248
# [644]	valid's binary_logloss: 0.108929	valid's f1: 0.920267
# [645]	valid's binary_logloss: 0.108917	valid's f1: 0.920328
# [646]	valid's binary_logloss: 0.108914	valid's f1: 0.920313
# [647]	valid's binary_logloss: 0.108902	valid's f1: 0.920349
# [648]	valid's binary_logloss: 0.108897	valid's f1: 0.920341
# [649]	valid's binary_logloss: 0.108887	valid's f1: 0.920349
# [650]	valid's binary_logloss: 0.108884	valid's f1: 0.920376
# [651]	valid's binary_logloss: 0.108878	valid's f1: 0.920392
# [652]	valid's binary_logloss: 0.108855	valid's f1: 0.920368
# [653]	valid's binary_logloss: 0.108851	valid's f1: 0.920347
# [654]	valid's binary_logloss: 0.10884	valid's f1: 0.920349
# [655]	valid's binary_logloss: 0.108837	valid's f1: 0.920351
# [656]	valid's binary_logloss: 0.108825	valid's f1: 0.920369
# [657]	valid's binary_logloss: 0.108818	valid's f1: 0.920401
# [658]	valid's binary_logloss: 0.108802	valid's f1: 0.920428
# [659]	valid's binary_logloss: 0.108796	valid's f1: 0.920383
# [660]	valid's binary_logloss: 0.108792	valid's f1: 0.92038
# [661]	valid's binary_logloss: 0.108789	valid's f1: 0.920351
# [662]	valid's binary_logloss: 0.108781	valid's f1: 0.920344
# [663]	valid's binary_logloss: 0.108776	valid's f1: 0.920328
# [664]	valid's binary_logloss: 0.108773	valid's f1: 0.92033
# [665]	valid's binary_logloss: 0.108769	valid's f1: 0.920347
# [666]	valid's binary_logloss: 0.108756	valid's f1: 0.920388
# [667]	valid's binary_logloss: 0.108753	valid's f1: 0.920355
# [668]	valid's binary_logloss: 0.108746	valid's f1: 0.920331
# [669]	valid's binary_logloss: 0.108739	valid's f1: 0.920364
# [670]	valid's binary_logloss: 0.108734	valid's f1: 0.920322
# [671]	valid's binary_logloss: 0.10872	valid's f1: 0.920322
# [672]	valid's binary_logloss: 0.108713	valid's f1: 0.920379
# [673]	valid's binary_logloss: 0.108706	valid's f1: 0.920361
# [674]	valid's binary_logloss: 0.108696	valid's f1: 0.920388
# [675]	valid's binary_logloss: 0.108692	valid's f1: 0.920408
# [676]	valid's binary_logloss: 0.108689	valid's f1: 0.920376
# [677]	valid's binary_logloss: 0.108682	valid's f1: 0.920395
# [678]	valid's binary_logloss: 0.108677	valid's f1: 0.92036
# [679]	valid's binary_logloss: 0.108667	valid's f1: 0.920376
# [680]	valid's binary_logloss: 0.10866	valid's f1: 0.920358
# [681]	valid's binary_logloss: 0.108655	valid's f1: 0.920355
# [682]	valid's binary_logloss: 0.108647	valid's f1: 0.920366
# [683]	valid's binary_logloss: 0.108644	valid's f1: 0.920376
# [684]	valid's binary_logloss: 0.108635	valid's f1: 0.920387
# [685]	valid's binary_logloss: 0.108631	valid's f1: 0.920425
# [686]	valid's binary_logloss: 0.108623	valid's f1: 0.920415
# [687]	valid's binary_logloss: 0.108616	valid's f1: 0.920417
# [688]	valid's binary_logloss: 0.108614	valid's f1: 0.920399
# [689]	valid's binary_logloss: 0.108608	valid's f1: 0.920399
# [690]	valid's binary_logloss: 0.108605	valid's f1: 0.920439
# [691]	valid's binary_logloss: 0.108599	valid's f1: 0.920447
# [692]	valid's binary_logloss: 0.108595	valid's f1: 0.920458
# [693]	valid's binary_logloss: 0.108594	valid's f1: 0.920461
# [694]	valid's binary_logloss: 0.108583	valid's f1: 0.920487
# [695]	valid's binary_logloss: 0.108575	valid's f1: 0.920497
# [696]	valid's binary_logloss: 0.108569	valid's f1: 0.920471
# [697]	valid's binary_logloss: 0.108567	valid's f1: 0.920462
# [698]	valid's binary_logloss: 0.108563	valid's f1: 0.920461
# [699]	valid's binary_logloss: 0.108552	valid's f1: 0.920402
# [700]	valid's binary_logloss: 0.108548	valid's f1: 0.920375
# [701]	valid's binary_logloss: 0.108534	valid's f1: 0.920367
# [702]	valid's binary_logloss: 0.108527	valid's f1: 0.920363
# [703]	valid's binary_logloss: 0.108523	valid's f1: 0.920365
# [704]	valid's binary_logloss: 0.108508	valid's f1: 0.920419
# [705]	valid's binary_logloss: 0.108506	valid's f1: 0.920402
# [706]	valid's binary_logloss: 0.108491	valid's f1: 0.92044
# [707]	valid's binary_logloss: 0.108487	valid's f1: 0.92042
# [708]	valid's binary_logloss: 0.108481	valid's f1: 0.920422
# [709]	valid's binary_logloss: 0.108466	valid's f1: 0.920486
# [710]	valid's binary_logloss: 0.10845	valid's f1: 0.920538
# [711]	valid's binary_logloss: 0.108441	valid's f1: 0.920511
# [712]	valid's binary_logloss: 0.108427	valid's f1: 0.920588
# [713]	valid's binary_logloss: 0.108425	valid's f1: 0.920626
# [714]	valid's binary_logloss: 0.10842	valid's f1: 0.920624
# [715]	valid's binary_logloss: 0.108408	valid's f1: 0.920619
# [716]	valid's binary_logloss: 0.108403	valid's f1: 0.920618
# [717]	valid's binary_logloss: 0.10839	valid's f1: 0.920624
# [718]	valid's binary_logloss: 0.108387	valid's f1: 0.920607
# [719]	valid's binary_logloss: 0.108381	valid's f1: 0.920606
# [720]	valid's binary_logloss: 0.108369	valid's f1: 0.920634
# [721]	valid's binary_logloss: 0.108367	valid's f1: 0.920663
# [722]	valid's binary_logloss: 0.108365	valid's f1: 0.920665
# [723]	valid's binary_logloss: 0.108355	valid's f1: 0.920682
# [724]	valid's binary_logloss: 0.108355	valid's f1: 0.920719
# [725]	valid's binary_logloss: 0.108351	valid's f1: 0.920726
# [726]	valid's binary_logloss: 0.108349	valid's f1: 0.920734
# [727]	valid's binary_logloss: 0.10834	valid's f1: 0.920757
# [728]	valid's binary_logloss: 0.108337	valid's f1: 0.920755
# [729]	valid's binary_logloss: 0.108332	valid's f1: 0.920746
# [730]	valid's binary_logloss: 0.10833	valid's f1: 0.920705
# [731]	valid's binary_logloss: 0.108321	valid's f1: 0.920711
# [732]	valid's binary_logloss: 0.108319	valid's f1: 0.920729
# [733]	valid's binary_logloss: 0.108309	valid's f1: 0.920729
# [734]	valid's binary_logloss: 0.108309	valid's f1: 0.920735
# [735]	valid's binary_logloss: 0.108298	valid's f1: 0.920753
# [736]	valid's binary_logloss: 0.108289	valid's f1: 0.92071
# [737]	valid's binary_logloss: 0.108288	valid's f1: 0.920755
# [738]	valid's binary_logloss: 0.108283	valid's f1: 0.920747
# [739]	valid's binary_logloss: 0.10828	valid's f1: 0.920747
# [740]	valid's binary_logloss: 0.108272	valid's f1: 0.920727
# [741]	valid's binary_logloss: 0.10826	valid's f1: 0.920745
# [742]	valid's binary_logloss: 0.108261	valid's f1: 0.92071
# [743]	valid's binary_logloss: 0.10826	valid's f1: 0.920694
# [744]	valid's binary_logloss: 0.108254	valid's f1: 0.920646
# [745]	valid's binary_logloss: 0.108247	valid's f1: 0.920662
# [746]	valid's binary_logloss: 0.108245	valid's f1: 0.920695
# [747]	valid's binary_logloss: 0.108242	valid's f1: 0.920706
# [748]	valid's binary_logloss: 0.108241	valid's f1: 0.920719
# [749]	valid's binary_logloss: 0.108233	valid's f1: 0.920762
# [750]	valid's binary_logloss: 0.10823	valid's f1: 0.920762
# [751]	valid's binary_logloss: 0.108225	valid's f1: 0.920755
# [752]	valid's binary_logloss: 0.108222	valid's f1: 0.920757
# [753]	valid's binary_logloss: 0.108215	valid's f1: 0.920803
# [754]	valid's binary_logloss: 0.108213	valid's f1: 0.920803
# [755]	valid's binary_logloss: 0.108212	valid's f1: 0.920785
# [756]	valid's binary_logloss: 0.108211	valid's f1: 0.920785
# [757]	valid's binary_logloss: 0.108203	valid's f1: 0.920738
# [758]	valid's binary_logloss: 0.108203	valid's f1: 0.920747
# [759]	valid's binary_logloss: 0.108199	valid's f1: 0.920717
# [760]	valid's binary_logloss: 0.108191	valid's f1: 0.92075
# [761]	valid's binary_logloss: 0.108191	valid's f1: 0.920749
# [762]	valid's binary_logloss: 0.108192	valid's f1: 0.920777
# [763]	valid's binary_logloss: 0.108188	valid's f1: 0.920786
# [764]	valid's binary_logloss: 0.108182	valid's f1: 0.920801
# [765]	valid's binary_logloss: 0.108182	valid's f1: 0.920775
# [766]	valid's binary_logloss: 0.10818	valid's f1: 0.920783
# [767]	valid's binary_logloss: 0.10818	valid's f1: 0.920791
# [768]	valid's binary_logloss: 0.108172	valid's f1: 0.920765
# [769]	valid's binary_logloss: 0.108172	valid's f1: 0.920765
# [770]	valid's binary_logloss: 0.108171	valid's f1: 0.920757
# [771]	valid's binary_logloss: 0.108166	valid's f1: 0.920782
# [772]	valid's binary_logloss: 0.108166	valid's f1: 0.920766
# [773]	valid's binary_logloss: 0.10816	valid's f1: 0.920775
# [774]	valid's binary_logloss: 0.108159	valid's f1: 0.920778
# [775]	valid's binary_logloss: 0.108155	valid's f1: 0.920786
# [776]	valid's binary_logloss: 0.108142	valid's f1: 0.920813
# [777]	valid's binary_logloss: 0.108135	valid's f1: 0.920801
# [778]	valid's binary_logloss: 0.108122	valid's f1: 0.920791
# [779]	valid's binary_logloss: 0.108119	valid's f1: 0.920793
# [780]	valid's binary_logloss: 0.108118	valid's f1: 0.920802
# [781]	valid's binary_logloss: 0.10811	valid's f1: 0.920829
# [782]	valid's binary_logloss: 0.108107	valid's f1: 0.920845
# [783]	valid's binary_logloss: 0.108106	valid's f1: 0.920846
# [784]	valid's binary_logloss: 0.108105	valid's f1: 0.920838
# [785]	valid's binary_logloss: 0.108102	valid's f1: 0.920811
# [786]	valid's binary_logloss: 0.108102	valid's f1: 0.920813
# [787]	valid's binary_logloss: 0.108097	valid's f1: 0.920829
# [788]	valid's binary_logloss: 0.108095	valid's f1: 0.920802
# [789]	valid's binary_logloss: 0.108074	valid's f1: 0.920825
# [790]	valid's binary_logloss: 0.108074	valid's f1: 0.920833
# [791]	valid's binary_logloss: 0.10807	valid's f1: 0.920824
# [792]	valid's binary_logloss: 0.108067	valid's f1: 0.920857
# [793]	valid's binary_logloss: 0.108063	valid's f1: 0.920866
# [794]	valid's binary_logloss: 0.108065	valid's f1: 0.920858
# [795]	valid's binary_logloss: 0.108059	valid's f1: 0.920813
# [796]	valid's binary_logloss: 0.108059	valid's f1: 0.92078
# [797]	valid's binary_logloss: 0.108057	valid's f1: 0.920796
# [798]	valid's binary_logloss: 0.108053	valid's f1: 0.920822
# [799]	valid's binary_logloss: 0.108049	valid's f1: 0.920813
# [800]	valid's binary_logloss: 0.108047	valid's f1: 0.920813
# [1]	valid's binary_logloss: 0.60313	valid's f1: 0
# ...
# [534]	valid's binary_logloss: 0.110696	valid's f1: 0.920686
# [535]	valid's binary_logloss: 0.110673	valid's f1: 0.920715
# [536]	valid's binary_logloss: 0.110653	valid's f1: 0.920715
# [537]	valid's binary_logloss: 0.110631	valid's f1: 0.920696
# [538]	valid's binary_logloss: 0.110609	valid's f1: 0.920715
# [539]	valid's binary_logloss: 0.110594	valid's f1: 0.920663
# [540]	valid's binary_logloss: 0.110575	valid's f1: 0.920657
# [541]	valid's binary_logloss: 0.110557	valid's f1: 0.920688
# [542]	valid's binary_logloss: 0.110537	valid's f1: 0.92068
# [543]	valid's binary_logloss: 0.110517	valid's f1: 0.920666
# [544]	valid's binary_logloss: 0.110496	valid's f1: 0.920611
# [545]	valid's binary_logloss: 0.110482	valid's f1: 0.920657
# [546]	valid's binary_logloss: 0.110462	valid's f1: 0.920667
# [547]	valid's binary_logloss: 0.110447	valid's f1: 0.920661
# [548]	valid's binary_logloss: 0.110423	valid's f1: 0.920687
# [549]	valid's binary_logloss: 0.110399	valid's f1: 0.920628
# [550]	valid's binary_logloss: 0.110379	valid's f1: 0.920675
# [551]	valid's binary_logloss: 0.110364	valid's f1: 0.920683
# [552]	valid's binary_logloss: 0.11035	valid's f1: 0.920655
# [553]	valid's binary_logloss: 0.11033	valid's f1: 0.920662
# [554]	valid's binary_logloss: 0.110304	valid's f1: 0.920706
# [555]	valid's binary_logloss: 0.110286	valid's f1: 0.920629
# [556]	valid's binary_logloss: 0.110268	valid's f1: 0.920628
# [557]	valid's binary_logloss: 0.110251	valid's f1: 0.920654
# [558]	valid's binary_logloss: 0.110227	valid's f1: 0.920679
# [559]	valid's binary_logloss: 0.110208	valid's f1: 0.920698
# [560]	valid's binary_logloss: 0.110188	valid's f1: 0.920682
# [561]	valid's binary_logloss: 0.110177	valid's f1: 0.920638
# [562]	valid's binary_logloss: 0.110151	valid's f1: 0.920657
# [563]	valid's binary_logloss: 0.110131	valid's f1: 0.920671
# [564]	valid's binary_logloss: 0.110118	valid's f1: 0.920643
# [565]	valid's binary_logloss: 0.1101	valid's f1: 0.920613
# [566]	valid's binary_logloss: 0.110081	valid's f1: 0.920648
# [567]	valid's binary_logloss: 0.110062	valid's f1: 0.92063
# [568]	valid's binary_logloss: 0.110043	valid's f1: 0.920616
# [569]	valid's binary_logloss: 0.110033	valid's f1: 0.920678
# [570]	valid's binary_logloss: 0.110014	valid's f1: 0.92071
# [571]	valid's binary_logloss: 0.109995	valid's f1: 0.92073
# [572]	valid's binary_logloss: 0.109977	valid's f1: 0.920697
# [573]	valid's binary_logloss: 0.109957	valid's f1: 0.920714
# [574]	valid's binary_logloss: 0.109931	valid's f1: 0.920709
# [575]	valid's binary_logloss: 0.109915	valid's f1: 0.920634
# [576]	valid's binary_logloss: 0.109899	valid's f1: 0.920588
# [577]	valid's binary_logloss: 0.109883	valid's f1: 0.920588
# [578]	valid's binary_logloss: 0.109874	valid's f1: 0.92058
# [579]	valid's binary_logloss: 0.109852	valid's f1: 0.920588
# [580]	valid's binary_logloss: 0.109839	valid's f1: 0.920569
# [581]	valid's binary_logloss: 0.109823	valid's f1: 0.920571
# [582]	valid's binary_logloss: 0.109803	valid's f1: 0.92058
# [583]	valid's binary_logloss: 0.10979	valid's f1: 0.920624
# [584]	valid's binary_logloss: 0.109773	valid's f1: 0.920606
# [585]	valid's binary_logloss: 0.109762	valid's f1: 0.920588
# [586]	valid's binary_logloss: 0.109742	valid's f1: 0.920621
# [587]	valid's binary_logloss: 0.109731	valid's f1: 0.920637
# [588]	valid's binary_logloss: 0.109725	valid's f1: 0.920622
# [589]	valid's binary_logloss: 0.109709	valid's f1: 0.920649
# [590]	valid's binary_logloss: 0.109688	valid's f1: 0.920633
# [591]	valid's binary_logloss: 0.109675	valid's f1: 0.920633
# [592]	valid's binary_logloss: 0.109662	valid's f1: 0.920665
# [593]	valid's binary_logloss: 0.109652	valid's f1: 0.920665
# [594]	valid's binary_logloss: 0.109645	valid's f1: 0.920655
# [595]	valid's binary_logloss: 0.109625	valid's f1: 0.920665
# [596]	valid's binary_logloss: 0.109611	valid's f1: 0.920735
# [597]	valid's binary_logloss: 0.109595	valid's f1: 0.920734
# [598]	valid's binary_logloss: 0.109587	valid's f1: 0.920743
# [599]	valid's binary_logloss: 0.109576	valid's f1: 0.920743
# [600]	valid's binary_logloss: 0.109567	valid's f1: 0.920743
# [601]	valid's binary_logloss: 0.109547	valid's f1: 0.920726
# [602]	valid's binary_logloss: 0.109538	valid's f1: 0.920747
# [603]	valid's binary_logloss: 0.109533	valid's f1: 0.92073
# [604]	valid's binary_logloss: 0.109519	valid's f1: 0.920714
# [605]	valid's binary_logloss: 0.109509	valid's f1: 0.920714
# [606]	valid's binary_logloss: 0.109494	valid's f1: 0.920722
# [607]	valid's binary_logloss: 0.109485	valid's f1: 0.920727
# [608]	valid's binary_logloss: 0.10947	valid's f1: 0.920709
# [609]	valid's binary_logloss: 0.109451	valid's f1: 0.920713
# [610]	valid's binary_logloss: 0.109442	valid's f1: 0.920708
# [611]	valid's binary_logloss: 0.109432	valid's f1: 0.920777
# [612]	valid's binary_logloss: 0.109421	valid's f1: 0.920787
# [613]	valid's binary_logloss: 0.109403	valid's f1: 0.920814
# [614]	valid's binary_logloss: 0.109393	valid's f1: 0.920797
# [615]	valid's binary_logloss: 0.109389	valid's f1: 0.920807
# [616]	valid's binary_logloss: 0.109381	valid's f1: 0.920802
# [617]	valid's binary_logloss: 0.109376	valid's f1: 0.92081
# [618]	valid's binary_logloss: 0.109366	valid's f1: 0.92081
# [619]	valid's binary_logloss: 0.109355	valid's f1: 0.92083
# [620]	valid's binary_logloss: 0.109338	valid's f1: 0.920859
# [621]	valid's binary_logloss: 0.10933	valid's f1: 0.920867
# [622]	valid's binary_logloss: 0.109319	valid's f1: 0.920885
# [623]	valid's binary_logloss: 0.109314	valid's f1: 0.920885
# [624]	valid's binary_logloss: 0.109297	valid's f1: 0.920897
# [625]	valid's binary_logloss: 0.109275	valid's f1: 0.92087
# [626]	valid's binary_logloss: 0.109252	valid's f1: 0.920853
# [627]	valid's binary_logloss: 0.109241	valid's f1: 0.92084
# [628]	valid's binary_logloss: 0.109219	valid's f1: 0.920837
# [629]	valid's binary_logloss: 0.109209	valid's f1: 0.92083
# [630]	valid's binary_logloss: 0.109195	valid's f1: 0.92082
# [631]	valid's binary_logloss: 0.109173	valid's f1: 0.920784
# [632]	valid's binary_logloss: 0.109156	valid's f1: 0.920758
# [633]	valid's binary_logloss: 0.109139	valid's f1: 0.920793
# [634]	valid's binary_logloss: 0.109117	valid's f1: 0.920784
# [635]	valid's binary_logloss: 0.109104	valid's f1: 0.920777
# [636]	valid's binary_logloss: 0.109082	valid's f1: 0.920768
# [637]	valid's binary_logloss: 0.109075	valid's f1: 0.920776
# [638]	valid's binary_logloss: 0.109059	valid's f1: 0.920786
# [639]	valid's binary_logloss: 0.109045	valid's f1: 0.920774
# [640]	valid's binary_logloss: 0.109024	valid's f1: 0.92076
# [641]	valid's binary_logloss: 0.109007	valid's f1: 0.920776
# [642]	valid's binary_logloss: 0.108993	valid's f1: 0.920738
# [643]	valid's binary_logloss: 0.108977	valid's f1: 0.920752
# [644]	valid's binary_logloss: 0.108968	valid's f1: 0.920785
# [645]	valid's binary_logloss: 0.108951	valid's f1: 0.9208
# [646]	valid's binary_logloss: 0.108932	valid's f1: 0.920802
# [647]	valid's binary_logloss: 0.10892	valid's f1: 0.920749
# [648]	valid's binary_logloss: 0.108911	valid's f1: 0.920808
# [649]	valid's binary_logloss: 0.1089	valid's f1: 0.920809
# [650]	valid's binary_logloss: 0.10889	valid's f1: 0.920834
# [651]	valid's binary_logloss: 0.108879	valid's f1: 0.920852
# [652]	valid's binary_logloss: 0.108868	valid's f1: 0.920808
# [653]	valid's binary_logloss: 0.108852	valid's f1: 0.920814
# [654]	valid's binary_logloss: 0.108845	valid's f1: 0.920844
# [655]	valid's binary_logloss: 0.108837	valid's f1: 0.920832
# [656]	valid's binary_logloss: 0.108825	valid's f1: 0.920833
# [657]	valid's binary_logloss: 0.108815	valid's f1: 0.92086
# [658]	valid's binary_logloss: 0.108803	valid's f1: 0.920842
# [659]	valid's binary_logloss: 0.108799	valid's f1: 0.920841
# [660]	valid's binary_logloss: 0.108791	valid's f1: 0.920825
# [661]	valid's binary_logloss: 0.10878	valid's f1: 0.920798
# [662]	valid's binary_logloss: 0.108772	valid's f1: 0.920853
# [663]	valid's binary_logloss: 0.108765	valid's f1: 0.920816
# [664]	valid's binary_logloss: 0.108755	valid's f1: 0.920833
# [665]	valid's binary_logloss: 0.108748	valid's f1: 0.920836
# [666]	valid's binary_logloss: 0.108743	valid's f1: 0.920861
# [667]	valid's binary_logloss: 0.108731	valid's f1: 0.920905
# [668]	valid's binary_logloss: 0.108725	valid's f1: 0.920946
# [669]	valid's binary_logloss: 0.108715	valid's f1: 0.920983
# [670]	valid's binary_logloss: 0.108705	valid's f1: 0.920988
# [671]	valid's binary_logloss: 0.108699	valid's f1: 0.920998
# [672]	valid's binary_logloss: 0.108692	valid's f1: 0.92098
# [673]	valid's binary_logloss: 0.108685	valid's f1: 0.920998
# [674]	valid's binary_logloss: 0.108677	valid's f1: 0.921008
# [675]	valid's binary_logloss: 0.108674	valid's f1: 0.921003
# [676]	valid's binary_logloss: 0.108666	valid's f1: 0.921027
# [677]	valid's binary_logloss: 0.108657	valid's f1: 0.921016
# [678]	valid's binary_logloss: 0.10865	valid's f1: 0.921026
# [679]	valid's binary_logloss: 0.10864	valid's f1: 0.921046
# [680]	valid's binary_logloss: 0.108634	valid's f1: 0.921036
# [681]	valid's binary_logloss: 0.108626	valid's f1: 0.921027
# [682]	valid's binary_logloss: 0.108618	valid's f1: 0.920992
# [683]	valid's binary_logloss: 0.108612	valid's f1: 0.920958
# [684]	valid's binary_logloss: 0.108601	valid's f1: 0.920998
# [685]	valid's binary_logloss: 0.108596	valid's f1: 0.921024
# [686]	valid's binary_logloss: 0.108589	valid's f1: 0.921007
# [687]	valid's binary_logloss: 0.108583	valid's f1: 0.921014
# [688]	valid's binary_logloss: 0.108577	valid's f1: 0.921012
# [689]	valid's binary_logloss: 0.108569	valid's f1: 0.921014
# [690]	valid's binary_logloss: 0.108565	valid's f1: 0.921006
# [691]	valid's binary_logloss: 0.10856	valid's f1: 0.921039
# [692]	valid's binary_logloss: 0.108548	valid's f1: 0.921048
# [693]	valid's binary_logloss: 0.108545	valid's f1: 0.921069
# [694]	valid's binary_logloss: 0.108526	valid's f1: 0.921052
# [695]	valid's binary_logloss: 0.108524	valid's f1: 0.921035
# [696]	valid's binary_logloss: 0.10852	valid's f1: 0.921003
# [697]	valid's binary_logloss: 0.108511	valid's f1: 0.920997
# [698]	valid's binary_logloss: 0.108505	valid's f1: 0.920997
# [699]	valid's binary_logloss: 0.108485	valid's f1: 0.92103
# [700]	valid's binary_logloss: 0.108483	valid's f1: 0.921047
# [701]	valid's binary_logloss: 0.108476	valid's f1: 0.92103
# [702]	valid's binary_logloss: 0.108472	valid's f1: 0.921046
# [703]	valid's binary_logloss: 0.108457	valid's f1: 0.92103
# [704]	valid's binary_logloss: 0.10845	valid's f1: 0.921015
# [705]	valid's binary_logloss: 0.10845	valid's f1: 0.921015
# [706]	valid's binary_logloss: 0.108442	valid's f1: 0.920993
# [707]	valid's binary_logloss: 0.108444	valid's f1: 0.920965
# [708]	valid's binary_logloss: 0.108436	valid's f1: 0.920991
# [709]	valid's binary_logloss: 0.108429	valid's f1: 0.921007
# [710]	valid's binary_logloss: 0.108425	valid's f1: 0.921043
# [711]	valid's binary_logloss: 0.108419	valid's f1: 0.921001
# [712]	valid's binary_logloss: 0.108419	valid's f1: 0.921001
# [713]	valid's binary_logloss: 0.108412	valid's f1: 0.920982
# [714]	valid's binary_logloss: 0.108413	valid's f1: 0.920973
# [715]	valid's binary_logloss: 0.108407	valid's f1: 0.920997
# [716]	valid's binary_logloss: 0.108401	valid's f1: 0.921017
# [717]	valid's binary_logloss: 0.108398	valid's f1: 0.920981
# [718]	valid's binary_logloss: 0.108392	valid's f1: 0.921026
# [719]	valid's binary_logloss: 0.108391	valid's f1: 0.921009
# [720]	valid's binary_logloss: 0.108384	valid's f1: 0.920965
# [721]	valid's binary_logloss: 0.108378	valid's f1: 0.920954
# [722]	valid's binary_logloss: 0.108376	valid's f1: 0.92099
# [723]	valid's binary_logloss: 0.108372	valid's f1: 0.921001
# [724]	valid's binary_logloss: 0.108369	valid's f1: 0.920974
# [725]	valid's binary_logloss: 0.108363	valid's f1: 0.920966
# [726]	valid's binary_logloss: 0.108355	valid's f1: 0.921015
# [727]	valid's binary_logloss: 0.10835	valid's f1: 0.921034
# [728]	valid's binary_logloss: 0.108346	valid's f1: 0.921019
# [729]	valid's binary_logloss: 0.108343	valid's f1: 0.921019
# [730]	valid's binary_logloss: 0.108334	valid's f1: 0.921068
# [731]	valid's binary_logloss: 0.108329	valid's f1: 0.921037
# [732]	valid's binary_logloss: 0.108324	valid's f1: 0.921063
# [733]	valid's binary_logloss: 0.108317	valid's f1: 0.921112
# [734]	valid's binary_logloss: 0.108314	valid's f1: 0.921068
# [735]	valid's binary_logloss: 0.108309	valid's f1: 0.921111
# [736]	valid's binary_logloss: 0.108301	valid's f1: 0.921106
# [737]	valid's binary_logloss: 0.108296	valid's f1: 0.921103
# [738]	valid's binary_logloss: 0.108285	valid's f1: 0.921086
# [739]	valid's binary_logloss: 0.108283	valid's f1: 0.921103
# [740]	valid's binary_logloss: 0.108281	valid's f1: 0.921113
# [741]	valid's binary_logloss: 0.108274	valid's f1: 0.921124
# [742]	valid's binary_logloss: 0.108271	valid's f1: 0.921124
# [743]	valid's binary_logloss: 0.108262	valid's f1: 0.921185
# [744]	valid's binary_logloss: 0.108261	valid's f1: 0.921133
# [745]	valid's binary_logloss: 0.108259	valid's f1: 0.921132
# [746]	valid's binary_logloss: 0.108252	valid's f1: 0.92108
# [747]	valid's binary_logloss: 0.108252	valid's f1: 0.92109
# [748]	valid's binary_logloss: 0.108246	valid's f1: 0.921103
# [749]	valid's binary_logloss: 0.108246	valid's f1: 0.921111
# [750]	valid's binary_logloss: 0.108238	valid's f1: 0.921126
# [751]	valid's binary_logloss: 0.108236	valid's f1: 0.921126
# [752]	valid's binary_logloss: 0.108227	valid's f1: 0.921185
# [753]	valid's binary_logloss: 0.108223	valid's f1: 0.921195
# [754]	valid's binary_logloss: 0.10822	valid's f1: 0.921197
# [755]	valid's binary_logloss: 0.108217	valid's f1: 0.921207
# [756]	valid's binary_logloss: 0.108211	valid's f1: 0.921209
# [757]	valid's binary_logloss: 0.108207	valid's f1: 0.921209
# [758]	valid's binary_logloss: 0.108206	valid's f1: 0.921249
# [759]	valid's binary_logloss: 0.108199	valid's f1: 0.921241
# [760]	valid's binary_logloss: 0.108199	valid's f1: 0.921241
# [761]	valid's binary_logloss: 0.108195	valid's f1: 0.921242
# [762]	valid's binary_logloss: 0.108191	valid's f1: 0.921258
# [763]	valid's binary_logloss: 0.108187	valid's f1: 0.921253
# [764]	valid's binary_logloss: 0.108186	valid's f1: 0.921272
# [765]	valid's binary_logloss: 0.108187	valid's f1: 0.921262
# [766]	valid's binary_logloss: 0.108183	valid's f1: 0.921269
# [767]	valid's binary_logloss: 0.108177	valid's f1: 0.921327
# [768]	valid's binary_logloss: 0.108177	valid's f1: 0.921343
# [769]	valid's binary_logloss: 0.108174	valid's f1: 0.921345
# [770]	valid's binary_logloss: 0.108173	valid's f1: 0.921337
# [771]	valid's binary_logloss: 0.108172	valid's f1: 0.921321
# [772]	valid's binary_logloss: 0.108169	valid's f1: 0.921296
# [773]	valid's binary_logloss: 0.108167	valid's f1: 0.921294
# [774]	valid's binary_logloss: 0.108162	valid's f1: 0.921302
# [775]	valid's binary_logloss: 0.108163	valid's f1: 0.921301
# [776]	valid's binary_logloss: 0.108157	valid's f1: 0.921327
# [777]	valid's binary_logloss: 0.108153	valid's f1: 0.921277
# [778]	valid's binary_logloss: 0.108154	valid's f1: 0.921268
# [779]	valid's binary_logloss: 0.108151	valid's f1: 0.921257
# [780]	valid's binary_logloss: 0.108144	valid's f1: 0.921258
# [781]	valid's binary_logloss: 0.108137	valid's f1: 0.921276
# [782]	valid's binary_logloss: 0.108137	valid's f1: 0.921282
# [783]	valid's binary_logloss: 0.108134	valid's f1: 0.921257
# [784]	valid's binary_logloss: 0.108132	valid's f1: 0.921246
# [785]	valid's binary_logloss: 0.108127	valid's f1: 0.921262
# [786]	valid's binary_logloss: 0.108119	valid's f1: 0.921204
# [787]	valid's binary_logloss: 0.108121	valid's f1: 0.921222
# [788]	valid's binary_logloss: 0.108118	valid's f1: 0.92124
# [789]	valid's binary_logloss: 0.108115	valid's f1: 0.92124
# [790]	valid's binary_logloss: 0.108114	valid's f1: 0.921292
# [791]	valid's binary_logloss: 0.108106	valid's f1: 0.921292
# [792]	valid's binary_logloss: 0.108106	valid's f1: 0.921292
# [793]	valid's binary_logloss: 0.1081	valid's f1: 0.92122
# [794]	valid's binary_logloss: 0.108093	valid's f1: 0.921261
# [795]	valid's binary_logloss: 0.108091	valid's f1: 0.921229
# [796]	valid's binary_logloss: 0.108089	valid's f1: 0.921238
# [797]	valid's binary_logloss: 0.108083	valid's f1: 0.921282
# [798]	valid's binary_logloss: 0.108079	valid's f1: 0.921293
# [799]	valid's binary_logloss: 0.108076	valid's f1: 0.92133
# [800]	valid's binary_logloss: 0.108072	valid's f1: 0.921346

# %%
lgbm800 = pd.read_csv('./output/submission/lgbm_800.csv').target.values

city=pd.DataFrame()
for i in range(size):
    city[str(i)]=np.round(city_lgbm_proba[i])
city[str(size)]=lgbm800
city['target']=city['0']
for i in range(1,size+1):
    city['target']=city['target']+city[str(i)]

def fnc(x):
    if x>=2:
        return 1
    else:
        return 0
city=[fnc(x) for x in city.target.values]
city[:20]
# Out:
# [0, 0, 1, 0, 0, 0, 1, 0, 1, 0, 1, 1, 0, 0, 0, 1, 0, 0, 0, 0]

# %%
submission= pd.DataFrame()

submission['id']=test2['trajectory_id']
submission['target'] = city
submission.to_csv('./output/submission/lgbm_blended_2.csv',index=False)    
submission[:20]
# Out:
#                                              id  target
# 0    traj_00032f51796fd5437b238e3a9823d13d_31_5       0
# 1   traj_000479418b5561ab694a2870cc04fd43_25_10       0
# 2    traj_000506a39775e5bca661ac80e3f466eb_29_5       1
# 3     traj_0005401ceddaf27a9b7f0d42ef1fbe95_1_4       0
# 4     traj_00063a4f6c12e1e4de7d876580620667_3_4       0
# 5    traj_0006535be25bb52dd06983447880c964_5_12       0
# 6    traj_0006f84bb33ec929d1cda7686f861d0a_31_3       1
# 7   traj_00093ae562586aed0e053b8431e8ace4_23_10       0
# 8    traj_000c739e444a70e1804d757a0580caaa_31_3       1
# 9    traj_000d479078af08618bddc7f09082b8c3_11_6       0
# 10  traj_000d6fba12a7d06defe90e3c9162c11e_29_11       1
# 11   traj_000efd6f95db39d6ba35027f02b5628f_9_20       1
# 12  traj_000feace3a33be9245e2783cdff467a8_15_12       0
# 13    traj_0011b48d0cf4f962833edd701afaf419_3_7       0
# 14   traj_001484cf0f956c316070be4b4c6352ff_29_7       0
# 15    traj_001d29060cfe35996cfeb141210ecbeb_9_2       1
# 16    traj_001dff40eab7eea1c10d0fadcea0c779_9_7       0
# 17   traj_001f9345a2979c553125c65499630f25_29_3       0
# 18   traj_002447d99e8f6c3bc6c1329140979a91_25_7       0
# 19   traj_002531dea45cd4059e92099630ebf775_3_10       0
